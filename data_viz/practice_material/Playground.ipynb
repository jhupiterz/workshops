# %% [markdown]
# # This notebook is your playground

# %% [markdown]
# Use this notebook to explore new datasets, try new plots, create new features.

# %%
import pandas as pd

# %%
exoplanet_df = pd.read_csv("data/exoplanets.csv")

# %%
exoplanet_df
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# ...

# %%
exoplanet_df["detection_method"] == "Transit"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5245     True
# 5246    False
# 5247    False
# 5248    False
# 5249    False
# Name: detection_method, Length: 5250, dtype: bool

# %%
exoplanet_df[exoplanet_df["detection_method"] == "Transit"]
# Out:
#                   name  distance  stellar_magnitude   planet_type  \
# 47    AU Microscopii b      32.0              8.810  Neptune-like
# 48    AU Microscopii c      32.0              8.810  Neptune-like
# 67         BD+20 594 b     585.0             10.849  Neptune-like
# 85          CoRoT-10 b    1104.0             15.293     Gas Giant
# 86          CoRoT-11 b    2137.0             12.897     Gas Giant
# ...                ...       ...                ...           ...
# 5241            XO-3 b     695.0              9.854     Gas Giant
# 5242            XO-4 b     889.0             10.814     Gas Giant
# 5243            XO-5 b     901.0             12.198     Gas Giant
# 5244            XO-6 b     768.0             10.247     Gas Giant
# 5245            XO-7 b     764.0             10.521     Gas Giant
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 47              2020          20.1200    Earth              0.363    Jupiter
# ...

# %%
exoplanet_df
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# ...

# %%
exoplanet_df["conv_factor_m"] = exoplanet_df["mass_wrt"].map({"Jupiter": 318, "Earth": 1})

# %%
exoplanet_df["total_mass_wrt_earth"] = exoplanet_df["conv_factor_m"] * exoplanet_df["mass_multiplier"]

# %%
exoplanet_df
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# ...

# %%
exoplanet_df["mass_wrt"].unique()
# Out:
# array(['Jupiter', 'Earth', nan], dtype=object)

# %%
exoplanet_df.shape
# Out:
# (5250, 13)

# %%
exoplanet_df.columns
# Out:
# Index(['name', 'distance', 'stellar_magnitude', 'planet_type',
#        'discovery_year', 'mass_multiplier', 'mass_wrt', 'radius_multiplier',
#        'radius_wrt', 'orbital_radius', 'orbital_period', 'eccentricity',
#        'detection_method'],
#       dtype='object')

# %%
exoplanet_df.dtypes
# Out:
# name                  object
# distance             float64
# stellar_magnitude    float64
# planet_type           object
# discovery_year         int64
# mass_multiplier      float64
# mass_wrt              object
# radius_multiplier    float64
# radius_wrt            object
# orbital_radius       float64
# orbital_period       float64
# eccentricity         float64
# detection_method      object
# dtype: object

# %%
max_distance = exoplanet_df["distance"].max()
max_distance
# Out:
# 27727.0

# %%
exoplanet_df[exoplanet_df["distance"] == max_distance]
# Out:
#              name  distance  stellar_magnitude planet_type  discovery_year  \
# 4785  SWEEPS-11 b   27727.0              19.83   Gas Giant            2006
# 4786   SWEEPS-4 b   27727.0              18.80   Gas Giant            2006
#
#       mass_multiplier mass_wrt  radius_multiplier radius_wrt  orbital_radius  \
# 4785              9.7  Jupiter               1.13    Jupiter           0.030
# 4786              3.8  Jupiter               0.81    Jupiter           0.055
#
#       orbital_period  eccentricity detection_method
# 4785        0.004928           0.0          Transit
# 4786        0.011499           0.0          Transit

# %%
exoplanet_df["detection_method"].nunique()
# Out:
# 11

# %%
exoplanet_df["detection_method"].value_counts()
# Out:
# Transit                          3945
# Radial Velocity                  1027
# Gravitational Microlensing        154
# Direct Imaging                     62
# Transit Timing Variations          24
# Eclipse Timing Variations          17
# Orbital Brightness Modulation       9
# Pulsar Timing                       7
# Astrometry                          2
# Pulsation Timing Variations         2
# Disk Kinematics                     1
# Name: detection_method, dtype: int64

# %%
exoplanet_df.groupby("planet_type").min()
# Out:
# /var/folders/8r/4jrrmbyd2hsbp5tjhv6zd1c00000gn/T/ipykernel_97067/211465787.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   exoplanet_df.groupby("planet_type").min()
#                               name  distance  stellar_magnitude  \
# planet_type
# Gas Giant     11 Comae Berenices b      10.0            0.87200
# Neptune-like         61 Virginis b      11.0            4.41540
# Super Earth            55 Cancri e       4.0            3.49607
# Terrestrial       EPIC 201497682 b      12.0            8.83400
# Unknown             KIC 10001893 b     516.0           12.02500
#
#               discovery_year  mass_multiplier  radius_multiplier  \
# planet_type
# Gas Giant               1995          0.12700              0.225
# Neptune-like            2002          0.42476              0.200
# ...

# %% [markdown]
# # Case study

# %% [markdown]
# For this case study, your goal is to reproduce the chart below:</br>
# ![case_study](data/case_study.png)

# %%
# mass_wrt_earth
# density = mass / kg
# volume_wrt_earth

# %%
exoplanet_df["conv_factor_r"] = exoplanet_df["radius_wrt"].map({"Jupiter": 11, "Earth": 1})

# %%
exoplanet_df["raidus_wrt_earth"] = exoplanet_df["conv_factor_r"]*exoplanet_df["radius_multiplier"]

# %%
exoplanet_df["volume"] = 4/3 * 3.14 * exoplanet_df["raidus_wrt_earth"]**3

# %%
exoplanet_df["density"] = exoplanet_df["total_mass_wrt_earth"]/exoplanet_df["volume"]

# %%
exoplanet_df
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# ...

# %%
import plotly.express as px

# %%
px.scatter(data_frame=exoplanet_df, x="distance", y="density", log_y = True)
# Out:
# <div>                            <div id="af963a38-1428-451c-a8c8-ecaa6a3df1dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af963a38-1428-451c-a8c8-ecaa6a3df1dd")) {                    Plotly.newPlot(                        "af963a38-1428-451c-a8c8-ecaa6a3df1dd",                        [{"hovertemplate":"distance=%{x}<br>density=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[304.0,409.0,246.0,58.0,69.0,408.0,249.0,454.0,313.0,235.0,235.0,419.0,154.0,110.0,131.0,393.0,210.0,1293.0,227.0,146.0,296.0,45.0,45.0,45.0,240.0,97.0,50.0,41.0,41.0,41.0,41.0,41.0,28.0,28.0,28.0,178.0,58.0,271.0,65.0,65.0,330.0,530.0,144.0,529.0,163.0,66.0,67.0,32.0,32.0,320.0,139.0,349
# ...
